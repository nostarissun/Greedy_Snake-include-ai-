# %%
import env

frame = env.Game(False, True)
frame.run_game()
# Out:
# pygame 2.2.0 (SDL 2.32.54, Python 3.8.20)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 成功加载已有Q模型！
# 成功加载已有目标模型！
# use gpu!
# tensor([[ 2.0855,  4.6795, -0.3365, -2.1762]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# action:0 || food(25, 22) || head(15, 15)
# tensor([[ 3.0445,  4.5350,  1.8150, -1.4284]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# action:0 || food(25, 22) || head(14, 15)
# tensor([[ 3.0445,  4.5350,  1.8150, -1.4284]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# action:0 || food(25, 22) || head(14, 15)
# tensor([[ 3.0445,  4.5350,  1.8150, -1.4284]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# action:0 || food(25, 22) || head(14, 15)
# tensor([[ 3.0445,  4.5350,  1.8150, -1.4284]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# action:0 || food(25, 22) || head(14, 15)
# tensor([[ 3.0445,  4.5350,  1.8150, -1.4284]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import re

def read_data_from_file(file_path):
    try:
        data = []
        # 改进的正则表达式：支持科学计数法
        pattern = r'[-+]?(?:\d+\.?\d*|\.\d+)(?:[eE][-+]?\d+)?'  # 匹配整数、小数、科学计数法
        with open(file_path, 'r', encoding='utf-8') as f:
            for line in f:
                match = re.search(pattern, line)
                if match:
                    num_str = match.group(0)
                    try:
                        num = float(num_str)
                        data.append(num)
                    except ValueError:
                        print(f"无法转换 '{num_str}'")
        return np.array(data)
    except FileNotFoundError:
        print(f"文件 {file_path} 未找到")
        return None

# 读取数据
loss_data = read_data_from_file('loss.txt')
reward_data = read_data_from_file('reward.txt')
max_reward_data = read_data_from_file('max_reward.txt')
length_data = read_data_from_file('length.txt')

# 绘图
fig, axes = plt.subplots(4, 1, figsize=(15, 20))
titles = ['Loss', 'Reward', 'Max Reward', 'Length']
datasets = [loss_data, reward_data, max_reward_data, length_data]

for ax, title, data in zip(axes, titles, datasets):
    if data is not None:
        ax.plot(data)
        ax.set_title(title)
        ax.set_xlabel('Episode')
        ax.set_ylabel(title)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import re

a = [1, 2, 3, 3, 2, 1, 10, 9]

# 直接使用 plt.plot 绘制折线图
plt.plot(a)
plt.xlabel('Episode')
plt.ylabel('Value')
plt.title('Line Plot')

# 显示图形
plt.tight_layout()
plt.show()
